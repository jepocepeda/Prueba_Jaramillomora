# %% [markdown]
# <img src="https://raw.githubusercontent.com/jepocepeda/Prueba_Jaramillomora/main/Logo_Jaramillo_Mora.png" width="300" height="240" align="right">

# %% [markdown]
# # Análisis Exploratorio de Datos (EDA) para cultivosmunicipio.csv
#
# ## Repositorio de GitHub
# El repositorio de GitHub utilizado para este proyecto se encuentra en el siguiente enlace: [https://github.com/jepocepeda/Prueba_Jaramillomora.git](https://github.com/jepocepeda/Prueba_Jaramillomora.git).
#
# ## Dataset
# El dataset utilizado para el análisis es `cultivosmunicipio.csv`, que contiene información sobre la participación anual de cultivos en diferentes municipios.
#
# ## Objetivo de la Actividad
# Como ingeniero de datos para la compañía Jaramillo Mora, se le ha proporcionado el archivo `cultivosmunicipio.csv`, el cual almacena datos sobre la participación anual de cultivos en cada municipio. El objetivo principal de esta actividad es realizar un análisis exploratorio de datos (EDA) utilizando herramientas y librerías de Python como Pandas, Matplotlib y otras relevantes, con el fin de extraer información valiosa y obtener insights que permitan comprender patrones, comportamientos y relaciones presentes en los datos. Este análisis incluirá la limpieza y procesamiento de los datos, la identificación de tendencias, estacionalidad, outliers y correlaciones entre los diferentes cultivos, así como la visualización de las variaciones geográficas y temporales en la participación de los cultivos. Además, se busca generar visualizaciones claras y concisas que permitan a los tomadores de decisiones de Jaramillo Mora tomar acciones basadas en datos precisos y verificables.

# %% [markdown]
# Presentado por:
# - Cepeda Ramos, Jefferson  <br>
#
#
# Fecha: 07/03/2025

# %% [markdown]
# ## Fundamento
#
# <figure>
#     <center>
#       <img src="https://datos.gob.es/sites/default/files/u322/grafico.jpg" alt="EDA_FE" width=800 height=800/>
#       <figcaption> EDA <a href="https://datos.gob.es/en/documentacion/practical-introductory-guide-exploratory-data-analysis">Source</a></figcaption>
#     </center>
# </figure>
#
# EDA (Exploratory Data Analysis) es un proceso sobre los datos para descubrir patrones, detectar anomalías, probar hipótesis y comprobar supuestos. Aunque es una tarea que puede ser transversal, es imprescindible previo a la tarea de modelación.
#
# El EDA se utiliza principalmente para:
# - Ver lo que los datos pueden revelar.
# - Proporciona una mejor comprensión de las variables del conjunto de datos y de las relaciones entre ellas.
# - Puede ayudar a determinar si las técnicas de modelación o el método de análisis que estás considerando es adecuado.
# - Ayuda a definir los pasos de limpieza, transformación y selección de datos.
# - Confirma o definine los procesos de modelación.
# - Entender si es posible alcanzar los objetivos propuestos.
# - Descubrir errores o limitaciones de los datos.
# - Clarificar y delimitar el problema (¿Qué pregunta intentas resolver?).
# - Ayuda a responder: ¿Cómo puedes añadir, transformar, seleccionar o eliminar features para sacar más provecho de tus datos?, entre otros aspectos.
#
# El proceso de EDA incluye:
#
# ¿Qué tipo de datos tienes y cómo tratar los diferentes tipos que encuentras?
#   + Tamaños: Columnas (atributos) y filas (registros, observaciones o instancias)
#   + Tipos de datos a nivel informático
#   + Tipos de datos a nivel estadístico
#   + Tipos  de datos por temporalidad
#
# ¿Qué valores ves?, Qué distribuciones encuentras? ¿Qué relaciones hay? ¿Qué patrones identificas? ¿Qué relaciones aportan o afectan a la solución del problema?
#   + Análisis estadístico desccriptivo: univariado, bivariado, multivariado
#   + Análisis estadístico inferencial
#
# ¿Qué errores hay en los datos y cómo se aborda esta situación?<br/>
#   + Hay información duplicada, errores de captura, typos, información erronea
#
# ¿Qué es lo que falta en los datos y cómo se aborda esta situación?<br/>
#   + Missing values
#
# ¿Hay valores atípicos?¿Cómo tratarlos? (No siempre se identifican en un análisis univariado, en ocasiones es necesario hacer un análsis conjunto o multivariado?
# En Series de tiempo el trato de los outliers puede ser diferente.<br/>
#   + Outliers.
#   Para su identificación podemos usar métodos univariados o multivariados. Es una línea de investigación. A nivel univariado podemos usar algún límite definido por experticia, la media y la desviación estandar bajo normalidad, el IQR, entre otros métodos.
#
#
#
# ><div class="alert alert-block alert-warning">
# <b>Algunas Reflexiones con el proceso EDA:</b> <ul>
#  <li> EL EDA no es un proceso con un conjunto de reglas y tareas estrictas a realizar. Depende del problema y de su contexto.</li>
#  <li> No siempre se dispone de información sobre el dataset como lo proporcionan los ejemplos de clase, cursos o de la Web. </li>
#  <li> En este proceso, es necesario mantener una comunicación fluida y continua con los expertos del tema. Esto no sólo puede ahorrarte tiempo y te da respuestas, también influye en las preguntas que hagas sobre los datos.</li>
#  <li> En ocasiones el experto no tiene suficiente conocimiento de los datos que tienen y del problema que desea solucionar. El EDA puede ayudar a clarificar y delimitar el problema, identificar otros problemas y establecer los alcances reales.</li>
#  <li> No se trata de crear un informe, sino de comprender el problema.</li>
#  <li> Estas buscando establecer una serie de hipótesis que deseas explorar al modelar. Buscas tener una mayor comprension e intuición de los datos.</li>
#  <li> Hay que pasar tiempo con los datos.</li>
#  <li> Evitar el sesgo de complejidad (tendencia a preferir las soluciones complejas a las simples). No siempre lo complejo y más sofisticado es lo mejor.</li>
#  <li> Los modelos son tan buenos como las preguntas y la comprensión que tengas de los datos y del problema.</li>
#  <li> GIGO: Garbage in, garbage out.</li>
# </ul>
# </div>

# %% [markdown]
# ## 0. Instalación de librerías

# %%
# Instalación de las librerías a usar
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib

# %%
# Importación de las librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt  # Corrección en la importación de pyplot

# %% [markdown]
# ## 1. Leer el archivo: cultivosmunicipio.csv

# %%
# Se carga el dataset, el cual previamente fue subido a Github para su lectura desde la web
dataset = 'https://raw.githubusercontent.com/jepocepeda/Prueba_Jaramillomora/refs/heads/main/cultivosmunicipio.csv'

# Dataset en local
#dataset = './cultivosmunicipio.csv'

# Leer el archivo CSV
try:
    # Leer el archivo con delimitador ","
    df = pd.read_csv(dataset, on_bad_lines='skip', delimiter=",")
    print("Archivo leído exitosamente.")
except FileNotFoundError:
    print(f"El archivo '{dataset}' no se encontró en el directorio actual.")
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {e}")
# Out:
# Archivo leído exitosamente.

# %% [markdown]
# ## 2. Mostrar los primeros 10 registros del archivo

# %%
# 2. Mostrar los primeros 10 registros del archivo
print("\nPrimeros 10 registros:\n")
print(df.head(10))
# Out:
# Primeros 10 registros:
#
#   Tipo_cultivo   Año  Id_municipio  Municipio  Id_cultivo          Cultivo  \
# 0     Frutales  2000         76001       Cali     2040202         Aguacate
# 1     Frutales  2000         76001       Cali       20436         Cítricos
# 2     Frutales  2000         76001       Cali     2043000          Guayaba
# 3     Frutales  2000         76001       Cali     2043700             Lulo
# 4     Frutales  2000         76001       Cali     2044700             Mora
# 5     Frutales  2000         76001       Cali     2046300  Tomate de Árbol
# 6     Frutales  2000         76020     Alcalá     2040202         Aguacate
# 7     Frutales  2000         76020     Alcalá       20436         Cítricos
# 8     Frutales  2000         76020     Alcalá     2045601             Piña
# 9     Frutales  2000         76036  Andalucia     2040202         Aguacate
#
#    Ciclo  Hectareas_sembradas  Hectareas_cosechadas  Produccion_toneladas  \
# ...

# %% [markdown]
# ## 3. Mostrar los últimos 10 registros del archivo

# %%
# 3. Mostrar los últimos 10 registros del archivo
print("\nÚltimos 10 registros:\n")
print(df.tail(10))
# Out:
# Últimos 10 registros:
#
#                                             Tipo_cultivo   Año  Id_municipio  \
# 13830                                           Frutales  2021         76622
# 13831                                           Frutales  2021         76736
# 13832                                        Oleaginosas  2021         76828
# 13833                                           Frutales  2021         76834
# 13834                                           Frutales  2021         76834
# 13835                                           Frutales  2021         76845
# 13836                                           Frutales  2021         76892
# 13837                                             Flores  2021         76892
# 13838  Cultivos para Condimentos y Bebidas Medicinale...  2021         76892
# 13839                                           Frutales  2021         76892
#
#         Municipio  Id_cultivo      Cultivo  Ciclo  Hectareas_sembradas  \
# ...

# %% [markdown]
# ## 4. Realizar un análisis genérico sencillo y rápido de la fuente de datos

# %%
print("\nEstadísticas descriptivas:\n")
df.describe()
# Out:
# Estadísticas descriptivas:
#                 Año  Id_municipio    Id_cultivo  Hectareas_sembradas  \
# count  13840.000000  13840.000000  1.384000e+04         13840.000000
# mean    2010.766185  76429.610477  1.798948e+06           537.342326
# std        6.429142    295.092036  5.524961e+05          2273.231785
# min     2000.000000  76001.000000  1.021400e+04             0.000000
# 25%     2005.000000  76126.000000  2.030300e+06             8.000000
# 50%     2011.000000  76364.000000  2.040902e+06            27.000000
# 75%     2016.000000  76670.000000  2.044500e+06           137.100000
# max     2021.000000  76895.000000  2.080300e+06         37247.400000
#
#        Hectareas_cosechadas  Produccion_toneladas
# count          13840.000000          1.384000e+04
# mean             477.357593          3.469182e+04
# std             2052.400464          2.355883e+05
# min                0.000000          0.000000e+00
# 25%                7.000000          6.000000e+01
# ...

# %%
# Información general del dataset
print("\nInformación del dataset:\n")
print(df.info())
# Out:
# Información del dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840 entries, 0 to 13839
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Tipo_cultivo                     13840 non-null  object
#  1   Año                              13840 non-null  int64
#  2   Id_municipio                     13840 non-null  int64
#  3   Municipio                        13840 non-null  object
#  4   Id_cultivo                       13840 non-null  int64
#  5   Cultivo                          13840 non-null  object
#  6   Ciclo                            13840 non-null  object
#  7   Hectareas_sembradas              13840 non-null  float64
#  8   Hectareas_cosechadas             13840 non-null  float64
#  9   Produccion_toneladas             13840 non-null  float64
#  10  Rendimiento_toneladas/hectareas  13837 non-null  object
# ...

# %%
# Se filtran los valores nulos del atributo 
print("\nInformación de los valores nulos:\n")
df[df['Rendimiento_toneladas/hectareas'].isnull()]
# Out:
# Información de los valores nulos:
#      Tipo_cultivo   Año  Id_municipio Municipio  Id_cultivo    Cultivo  Ciclo  \
# 6684     Frutales  2010         76275   Florida     2043800  Macadamia  Anual
# 6692     Frutales  2010         76606  Restrepo     2043800  Macadamia  Anual
# 6694     Frutales  2010         76892     Yumbo     2046800     Zapote  Anual
#
#       Hectareas_sembradas  Hectareas_cosechadas  Produccion_toneladas  \
# 6684                 30.0                   0.0                   0.0
# 6692                  9.0                   0.0                   0.0
# 6694                  1.0                   0.0                   0.0
#
#      Rendimiento_toneladas/hectareas
# 6684                             NaN
# 6692                             NaN
# 6694                             NaN

# %% [markdown]
# #### Análisis de los valores nulos en "Rendimiento_toneladas/hectareas"
#
# Los tres registros con valores nulos en **"Rendimiento_toneladas/hectareas"** tienen en común que:
# - **Son del tipo de cultivo "Frutales"**
# -  **Pertenecen al año 2010**
# -   **Tienen 0 hectáreas cosechadas y 0 toneladas producidas**
# -   **El cultivo de Macadamia y Zapote aparece con NaN en rendimiento**
#
# ### Problema con estos valores nulos
# Como no se cosechó nada (**0 hectáreas**) y no hubo producción (**0 toneladas**), el rendimiento **no puede calcularse** debido a la división por cero.
#
# ###  Conclusión
# Mantener estos registros **no aporta información útil** y puede distorsionar análisis posteriores, por lo que **se recomienda eliminarlos**.

# %%
# Eliminación de los 3 registros NA en 'Rendimiento_toneladas/hectareas'
df = df.dropna(subset=['Rendimiento_toneladas/hectareas'])
df.isnull().sum()
# Out:
# Tipo_cultivo                       0
# Año                                0
# Id_municipio                       0
# Municipio                          0
# Id_cultivo                         0
# Cultivo                            0
# Ciclo                              0
# Hectareas_sembradas                0
# Hectareas_cosechadas               0
# Produccion_toneladas               0
# Rendimiento_toneladas/hectareas    0
# dtype: int64

# %%
scatter_matrix(df, figsize=(15, 15), diagonal='hist')  # Aumenta el tamaño
plt.show()

# %% [markdown]
# ### ¿Cuáles son los años que están referenciados en el archivo?

# %%
# 5. ¿Cuáles son los años que están referenciados en el archivo?
print("\nAños referenciados en el archivo:\n")
print(df['Año'].unique())
# Out:
# Años referenciados en el archivo:
#
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021]

# %% [markdown]
# ### 6. ¿Cuáles son las columnas del archivo?

# %%
print("\nAños referenciados en el archivo:")
print(df['Año'].unique())
# Out:
# Años referenciados en el archivo:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 2020 2021]

# %% [markdown]
# ### 7. ¿Cuáles son los municipios referenciados en el archivo?

# %%
# 7. ¿Cuáles son los municipios referenciados en el archivo?
print("\nMunicipios referenciados en el archivo:")
print(df['Municipio'].unique())
# Out:
# Municipios referenciados en el archivo:
# ['Cali' 'Alcalá' 'Andalucia' 'Ansermanuevo' 'Argelia' 'Bolivar'
#  'Buenaventura' 'Buga' 'Bugalagrande' 'Caicedonia' 'Candelaria' 'Cartago'
#  'Dagua' 'Calima Darién' 'El Aguila' 'El Cairo' 'El Cerrito' 'El Dovio'
#  'Florida' 'Ginebra' 'Guacarí' 'Jamundí' 'La Cumbre' 'La Unión'
#  'La Victoria' 'Obando' 'Palmira' 'Pradera' 'Restrepo' 'Riofrío'
#  'Roldanillo' 'San Pedro' 'Sevilla' 'Toro' 'Trujillo' 'Tuluá' 'Ulloa'
#  'Versalles' 'Vijes' 'Yotoco' 'Yumbo' 'Zarzal']

# %% [markdown]
# ### 8. Grafique un diagrama de barras de al menos 5 cultivos del municipio de Cali agrupados por toneladas de cultivos

# %%
# Filtrar solo datos de Cali
df_cali = df[df['Municipio'] == 'Cali']

# Agrupar por cultivo y sumar la producción
df_cali_grouped = df_cali.groupby('Cultivo', as_index=False)['Produccion_toneladas'].sum()

# Seleccionar los cultivos con mayor producción (al menos 5)
df_cali_top = df_cali_grouped.nlargest(5, 'Produccion_toneladas')

# Gráfico de barras con la corrección
plt.figure(figsize=(10, 6))
sns.barplot(data=df_cali_top, x='Cultivo', y='Produccion_toneladas', hue='Cultivo', palette="husl", legend=False)
plt.xlabel("Cultivo")
plt.ylabel("Producción (Toneladas)")
plt.title("Producción de los principales cultivos en Cali")
plt.xticks(rotation=45)
plt.show()

# %%
# Agrupar por cultivo y sumar la producción
df_cali_grouped = df_cali.groupby('Cultivo', as_index=False)['Produccion_toneladas'].sum()

# Ordenar de mayor a menor producción
df_cali_grouped = df_cali_grouped.sort_values(by='Produccion_toneladas', ascending=False)

# Mostrar la tabla
df_cali_grouped
# Out:
#               Cultivo  Produccion_toneladas
# 7      Caña de azúcar           10724915.00
# 20            Plátano              13682.00
# 9            Cítricos              13678.00
# 6                Café              11235.00
# 13            Guayaba               4693.00
# 22               Yuca               4405.00
# 21    Tomate de Árbol               1476.00
# 0            Aguacate               1390.00
# 18               Mora               1302.00
# 8       Cebolla Larga               1182.00
# 4              Banano                941.00
# 15               Lulo                782.00
# 17              Mango                479.00
# 19            Naranja                461.97
# 14              Limón                100.00
# 1                 Ají                 94.00
# 10  Flores y follajes                 74.00
# 2          Aromáticas                 64.50
# 16          Mandarina                 57.44
# 3           Arracacha                 48.00
# ...

# %%
# Eliminar la caña de azúcar
df_cali_filtered = df_cali_grouped[df_cali_grouped['Cultivo'] != 'Caña de azúcar']

# Seleccionar los 5 cultivos con mayor producción (sin caña de azúcar)
df_cali_top = df_cali_filtered.nlargest(5, 'Produccion_toneladas')

# Gráfico de barras con la corrección
plt.figure(figsize=(10, 6))
sns.barplot(data=df_cali_top, x='Cultivo', y='Produccion_toneladas', hue='Cultivo', palette="husl", legend=False)
plt.xlabel("Cultivo")
plt.ylabel("Producción (Toneladas)")
plt.title("Producción de los principales cultivos en Cali (sin Caña de Azúcar)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 9. Liste la cantidad de cultivos por toneladas del año 2021

# %%
df_2021 = df[df['Año'] == 2021]
print("\nCantidad de cultivos por toneladas en 2021:\n")
print(df_2021.groupby("Cultivo")["Produccion_toneladas"].sum().reset_index())
# Out:
# Cantidad de cultivos por toneladas en 2021:
#
#             Cultivo  Produccion_toneladas
# 0          Aguacate          2.577681e+04
# 1     Aguacate Hass          3.343460e+04
# 2               Ají          4.746000e+03
# 3             Arazá          2.000000e+00
# 4        Aromáticas          7.080500e+02
# 5         Arracacha          6.599000e+03
# 6          Bananito          1.695000e+03
# 7            Banano          6.183720e+04
# 8            Borojó          5.000000e+03
# 9             Cacao          7.420000e+02
# 10             Café          4.284200e+04
# 11   Caña de azúcar          2.425148e+07
# 12    Caña panelera          2.687070e+05
# 13    Cebolla Larga          3.317000e+03
# 14       Chontaduro          7.793000e+03
# 15             Coco          3.500000e+01
# 16           Curuba          1.622000e+02
# 17          Durazno          1.200000e+01
# 18            Fresa          6.163000e+02
# 19       Granadilla          2.300132e+03
# ...

# %% [markdown]
# ## Gráfico tipo "pie" de la producción de Vid del año 2021

# %%
# 10. Gráfico tipo "pie" de la producción de Vid del año 2021
df_vid_2021 = df_2021[df_2021['Cultivo'] == 'Vid']

if not df_vid_2021.empty:
    plt.figure(figsize=(8, 8))
    plt.pie(df_vid_2021['Produccion_toneladas'], labels=df_vid_2021['Municipio'], autopct='%1.1f%%', colors=sns.color_palette("pastel"))
    plt.title("Producción de Vid en 2021 por Municipio")
    plt.show()
else:
    print("\nNo hay datos de producción de Vid en el año 2021.")
